# %%
import numpy as np
from sklearn import linear_model
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import itertools
import operator
# %matplotlib inline

# %% [markdown]
# # Reading Data

# %%
df_train = pd.read_csv("votes-train.csv")
df_test = pd.read_csv("votes-test.csv")
df_train.head(20)
# Out:
#     Democrat  population  population_change  age65plus  Black  Hispanic  \
# 0          0       55395                1.5       13.8  0.187     0.027
# 1          0        8433               -2.0       19.3  0.008     0.028
# 2          0       15080                0.7       18.4  0.036     0.025
# 3          0       29317               -1.0       15.6  0.030     0.113
# 4          0       68838               -0.7       19.9  0.045     0.058
# 5          0       20652                1.0       17.6  0.022     0.033
# 6          0        3430                0.0       12.3  0.004     0.034
# 7          0      163820                1.4       15.6  0.073     0.027
# 8          0       66600               -1.8       19.5  0.099     0.041
# 9          0       21362               -1.4       18.7  0.006     0.030
# 10         0        4508               -5.2       17.8  0.005     0.010
# 11         0        1850                0.2       18.7  0.004     0.025
# 12         0        8996               -2.7       24.6  0.005     0.020
# 13         0       44943                5.2       21.1  0.024     0.219
# 14         0        6679               -2.6       15.0  0.041     0.037
# 15         0        6598                2.9       19.6  0.007     0.022
# 16         1      435286               -1.5       14.6  0.197     0.067
# 17         0       15994               -1.7       18.3  0.291     0.015
# 18         0       86697                3.7       15.3  0.095     0.023
# 19         1      213869                4.9       10.4  0.406     0.064
#
#     Edu_bachelors  income  Poverty  Density
# 0            20.9   53682     12.1     91.8
# 1            19.9   51793      9.1     13.7
# 2             9.0   38019     18.4     26.7
# 3            13.7   39267     20.6     23.2
# 4            12.5   33159     22.7     91.9
# 5            14.8   44149     16.9     20.7
# 6            15.9   37607     39.3      2.9
# 7            36.0   58080     13.9    390.5
# 8            17.0   36334     21.5    120.2
# 9            20.0   53057      8.3     41.4
# 10           12.4   19986     37.7     24.1
# 11           16.4   71250      7.4      2.6
# 12           14.3   42025      9.0     13.3
# 13           21.9   48115     16.3     43.0
# 14           15.4   64574      8.7      5.3
# 15           19.7   48911     13.2      4.3
# 16           23.4   41556     20.8   1296.2
# 17           13.8   37388     20.6     28.6
# 18           15.5   50786     15.2    132.3
# 19           26.1   60781     11.2    633.0

# %% [markdown]
# # Logistic Regression Function
# Trains the model using xtr (input) and ytr (target) and returns the accuracy test for both training (xtr, ytr)and testing samples (xts, yts)

# %%
def logistic_calc(xtr, ytr, xts, yts):
    logreg = linear_model.LogisticRegression(C=1e5)
    logreg.fit(xtr,ytr)
    yhat_tr = logreg.predict(xtr)
    yhat_ts = logreg.predict(xts)
    return accuracy_score(yhat_tr, ytr), accuracy_score(yhat_ts, yts)

# %% [markdown]
# # Logistic Regression Using all Features

# %%
#Preparing training and testing inputs and target matrices
#using all features
xtr = np.array(df_train[df_train.columns[1:]])
ytr = np.array(df_train['Democrat'])
xts = np.array(df_test[df_test.columns[1:]])
yts = np.array(df_test['Democrat'])


#feature scaling of input matrices xtr, xts
xtr = (xtr - np.mean(xtr, axis=0))/(np.std(xtr, axis=0))
xts = (xts - np.mean(xts, axis=0))/(np.std(xts, axis=0))


accuracy_tr, accuracy_ts = logistic_calc(xtr, ytr, xts, yts)
print("Accuracy with Training samples=", accuracy_tr)
print("Accuracy with Test samples", accuracy_ts)
# Out:
# Accuracy with Training samples= 0.914310197087
# Accuracy with Test samples 0.911196911197

# %% [markdown]
# # Subset Regression
# In this section, I trained and predicted Logistic Regression using all possible combinations of features which was factorial(9)=362880. Then I selected top 5 best models to analyze.

# %%
#returns np array made of columns named i feature list
def colum(df, feature):
    return np.column_stack([ np.array(df[f]) for f in feature])

# %%
features = df.columns[1:]
all_accuracy = {}
for r in range(1, len(features)+1):
    all_comb = itertools.combinations(features, r)
    print(all_comb)
    for comb in all_comb:
        
        xtr = colum(df_train, comb)
        ytr = np.array(df_train['Democrat'])
        xts = colum(df_test, comb)
        yts = np.array(df_test['Democrat'])


        #feature scaling of input matrices xtr, xts
        xtr = (xtr - np.mean(xtr, axis=0))/(np.std(xtr, axis=0))
        xts = (xts - np.mean(xts, axis=0))/(np.std(xts, axis=0))


        accuracy_tr, accuracy_ts = logistic_calc(xtr, ytr, xts, yts)
        all_accuracy[comb] = (accuracy_tr + accuracy_ts)/2
# Out:
# <itertools.combinations object at 0x11459edb8>
# <itertools.combinations object at 0x11459ef98>
# <itertools.combinations object at 0x11459edb8>
# <itertools.combinations object at 0x11459ef98>
# <itertools.combinations object at 0x11459df48>
# <itertools.combinations object at 0x11458a0e8>
# <itertools.combinations object at 0x11459df48>
# <itertools.combinations object at 0x11459edb8>
# <itertools.combinations object at 0x11459df48>

# %%
#sorting all results with accuracy
sorted_x = sorted(all_accuracy.items(), key=operator.itemgetter(1))
sorted_x.reverse()
for i in range(0, len(sorted_x)):
    print("Features\n", [key for key in pair[0]], sep='')
    print("Avg. Accuracy=", pair[1], '\n')
# Out:
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ...
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058
#
# Features
# ['population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density']
# Avg. Accuracy= 0.914255607058

# %% [markdown]
# # Ploting Best 500 Accuracy

# %%
best_acc =[]
best_feature = []

for pair in sorted_x[:500]:
    best_acc.append(pair[1])
    best_feature.append(pair[0])

plt.plot([i for i in range(1,501)], best_acc)
plt.ylabel('Accuracy')
plt.xlabel('Rank')
# Out:
# Text(0.5,0,'Rank')

# %%
plt.plot([i for i in range(1,501)], [len(i) for i in best_feature])
plt.ylabel('Best Performance : Number of Features')
plt.xlabel('Rank')
# Out:
# Text(0.5,0,'Rank')

# %%
print("Followings are top 5 features combination\n")
for i in range(5):
    print(best_feature[i],end='\n\n')
# Out:
# Followings are top 5 features combination
#
# ('population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty', 'Density')
#
# ('population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty')
#
# ('population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income', 'Poverty')
#
# ('population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'Poverty', 'Density')
#
# ('population', 'population_change', 'Black', 'Hispanic', 'Edu_bachelors', 'income')

# %% [markdown]
# # Ploting 20 Worst Accuracy

# %%
worst_acc =[]
worst_feature = []

for pair in sorted_x[len(sorted_x)-1:len(sorted_x)-21:-1]:
    worst_acc.append(pair[1])
    worst_feature.append(pair[0])

plt.plot([i for i in range(20,0,-1)], worst_acc)
plt.ylabel('Accuracy')
plt.xlabel('Rank')
# Out:
# Text(0.5,0,'Rank')

# %%
plt.plot([i for i in range(20, 0, -1)], [len(i) for i in worst_feature])
plt.ylabel('Worst Performance : Number of Features')
plt.xlabel('Rank')
# Out:
# Text(0.5,0,'Rank')

# %%
print("Followings are 20 worst feature combinations")
for f in worst_feature:
    print(f)
# Out:
# Followings are 20 worst feature combinations
# ('age65plus', 'income')
# ('population_change', 'age65plus', 'income')
# ('age65plus',)
# ('population_change', 'age65plus')
# ('population_change',)
# ('population_change', 'age65plus', 'Hispanic')
# ('population_change', 'age65plus', 'Hispanic', 'income')
# ('population_change', 'income')
# ('age65plus', 'Hispanic')
# ('income',)
# ('age65plus', 'Hispanic', 'income')
# ('Poverty',)
# ('population_change', 'Poverty')
# ('age65plus', 'Poverty')
# ('population_change', 'age65plus', 'Poverty')
# ('population_change', 'Hispanic', 'income')
# ('population_change', 'Hispanic')
# ('population_change', 'age65plus', 'Hispanic', 'Poverty')
# ('age65plus', 'Hispanic', 'Poverty')
# ('Hispanic', 'income')

# %% [markdown]
# # Ploting Best Pair Feature Accuracy

# %%
#Finding top accuracy with two features
best_pair = []
i = 0
while(len(best_pair) < 10 and i <len(sorted_x)):
    if(len(sorted_x[i][0]) ==2):
        best_pair.append(sorted_x[i])
    i+=1
    
print("Best pair features=\n")
for pair in best_pair:
    print(pair[0][0], pair[0][1], sep=" & ")
    print("Accuracy=",pair[1], end="\n\n")
# Out:
# Best pair features=
#
# population & Black
# Accuracy= 0.902248282068
#
# Black & Edu_bachelors
# Accuracy= 0.896031635749
#
# Black & Density
# Accuracy= 0.887449421511
#
# Black & Hispanic
# Accuracy= 0.881236083678
#
# Edu_bachelors & Poverty
# Accuracy= 0.878026851677
#
# population & Edu_bachelors
# Accuracy= 0.877380869669
#
# Black & income
# Accuracy= 0.875664592246
#
# population & Density
# Accuracy= 0.872236173007
#
# population & Poverty
# Accuracy= 0.870949998842
#
# population_change & Black
# Accuracy= 0.869873086454

# %%
#Plots two features with class
#Modified version from Intro to ML (see refrences in report) example codes
def plot_cnt(X,y):
    
    # Compute the bin edges for the 2d histogram
    x0val = np.array(list(set(X[:,0]))).astype(float)
    x1val = np.array(list(set(X[:,1]))).astype(float)
    x0, x1 = np.meshgrid(x0val,x1val)
    x0e= np.hstack((x0val,np.max(x0val)+1))
    x1e= np.hstack((x1val,np.max(x1val)+1))

    # Make a plot for each class
    yval = list(set(y))
    color = ['b','r']
    for i in range(len(yval)):
        I = np.where(y==yval[i])[0]
        cnt, x0e, x1e = np.histogram2d(X[I,0],X[I,1],[x0e,x1e])
        x0, x1 = np.meshgrid(x0val,x1val)
        plt.scatter(x0.ravel(), x1.ravel(), s=2*cnt.ravel(),alpha=0.5,
                    c=color[i],edgecolors='none')
    plt.legend(['Democrat','Republican'], loc='upper right')
    #plt.xlabel(xnames[0], fontsize=16)
    #plt.ylabel(xnames[1], fontsize=16)
    return plt

# %%
def plot_norm(x,y,ax):
    Iben = (y==0)
    Imal = (y==1)
    ax.plot(x[Imal,0],x[Imal,1],'b.')
    ax.plot(x[Iben,0] ,x[Iben,1],'r.')
    ax.legend(['Democrat', 'Republican'])

# %%
for i in range(10):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    x= np.column_stack((np.array(df_train[best_pair[i][0][0]]),np.array(df_train[best_pair[i][0][1]])))    
    y=np.array(df_train['Democrat'])
    #ax.scatter()
    plot_norm(x,y, ax)
    plt.xlabel(best_pair[i][0][0])
    plt.ylabel(best_pair[i][0][1])
    #break
